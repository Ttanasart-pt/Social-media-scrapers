# %%
import requests
URL = f"https://pantip.com/topic/41497035"
page = requests.get(URL)
print(page.text)
# Out:
# <!DOCTYPE HTML>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="th" lang="th">
# 	<head>
# 		<link rel="icon" href="/fav-icon.ico" type="image/x-icon" />
# 		<link rel="apple-touch-icon" href="//ptcdn.info/images/apple-touch-icon.png">
# 		<meta http-equiv="Content-Type" content="text/html" charset="UTF-8" />
# 		<title>เรียนจบมายังไม่ถึงปีแต่ที่บ้านก็เร่งให้หางานทำ - Pantip</title>
# 		<script src="https://frukt.pantip.com/kokos.js?t=1111111169"></script>
# 		<script id="ptConfig" type="application/json">{"gm_key":"BDdIvrC7jfPPn-MwdmvcAIzaSyTDGjLimAPlejZiP"}</script>
# 				<script type="text/javascript" data-cfasync="false" src="/js/version/1646276777/html5.js"></script>
# <script type="text/javascript" data-cfasync="false" src="/js/version/1646276777/lastest_jquery.js"></script>
# <script type="text/javascript" data-cfasync="false" src="/js/version/1646276777/common.js"></script>
# ...
